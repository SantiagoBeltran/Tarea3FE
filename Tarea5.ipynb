# %%
# %pylab inline
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a=1
b=10
def M(T):
    M=a*tanh(b/T)
    return M
T=np.arange(1,20,0.001)

# %%
plt.figure()
plt.plot(T,M(T))

# %%
def C(T):
    C=a*(b/T)**2*(cosh(b/T))**-2
    return C

# %%
plt.figure()
plt.plot(T,C(T))

# %%
d=5
def X(T):
    X=d*T**(-2)*(cosh(b/T))**-2
    return X

# %%
plt.figure()
plt.plot(T,X(T))
